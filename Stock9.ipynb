# %% [markdown]
# <a href="https://colab.research.google.com/github/saksheesawant215/Entrepot-Optimise1-Storage-Optimizer/blob/main/Stock9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense


from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("NSE-Tata.csv")
df2=df.copy()
df.head()
# Out:
#          Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-10-08  208.00  222.25  ...  215.15             4642146.0         10062.83
# 1  2018-10-05  217.00  218.60  ...  209.20             3519515.0          7407.06
# 2  2018-10-04  223.50  227.80  ...  218.20             1728786.0          3815.79
# 3  2018-10-03  230.00  237.50  ...  227.60             1708590.0          3960.27
# 4  2018-10-01  234.55  234.60  ...  230.90             1534749.0          3486.05
#
# [5 rows x 8 columns]

# %%
data.head()
# Out:
#                  Date    Open  ...  Total Trade Quantity  Turnover (Lacs)
# Date                           ...
# 2013-10-08 2013-10-08  157.00  ...             1720413.0          2688.94
# 2013-10-09 2013-10-09  155.70  ...             2049580.0          3204.49
# 2013-10-10 2013-10-10  156.00  ...             3124853.0          4978.80
# 2013-10-11 2013-10-11  161.15  ...             1880046.0          3030.76
# 2013-10-14 2013-10-14  160.85  ...             1281419.0          2039.09
#
# [5 rows x 8 columns]

# %% [markdown]
#  Analyze the closing prices from dataframe:

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']

plt.figure(figsize=(16,8))
plt.plot(df["Close"],label='Close Price history')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dropout,Dense

data=df.sort_index(ascending=True,axis=0)
new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Close'])

for i in range(0,len(data)):
    new_dataset["Date"][i]=data['Date'][i]
    new_dataset["Close"][i]=data["Close"][i]
    

new_dataset.index=new_dataset.Date
new_dataset.drop("Date",axis=1,inplace=True)

final_dataset=new_dataset.values

train_data=final_dataset[0:987,:]
valid_data=final_dataset[987:,:]

scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(final_dataset)

# %%
final_dataset
# Out:
# array([[155.8],
#        [155.55],
#        [160.15],
#        ...,
#        [218.2],
#        [209.2],
#        [215.15]], dtype=object)

# %%
scaled_data
# Out:
# array([[0.23823398],
#        [0.2371134 ],
#        [0.25773196],
#        ...,
#        [0.51792918],
#        [0.47758853],
#        [0.50425818]])

# %%
x_train_data,y_train_data=[],[]

for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)

x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))

# %%
lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
# Out:
# 927/927 - 28s - loss: 5.1310e-04

# %%
inputs_data=new_dataset[len(new_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)

# %%
X_test=[]
for i in range(60,inputs_data.shape[0]):
    X_test.append(inputs_data[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
closing_price=lstm_model.predict(X_test)
closing_price=scaler.inverse_transform(closing_price)

# %%
train_data=new_dataset[:987]
valid_data=new_dataset[987:]
valid_data['Predictions']=closing_price
plt.figure(figsize=(16,8))
plt.title('Model',fontsize=20)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Prince',fontsize=18)
plt.plot(train_data["Close"])
plt.plot(valid_data[['Close',"Predictions"]])
plt.legend(['Train','Val','Predictions'])
print("RMSE VALUE:",np.sqrt(np.mean(valid_data['Predictions']-valid_data['Close'])**2))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# RMSE VALUE: 7.9248841931743

# %%
rmse=np.sqrt(np.mean(valid_data['Predictions']-valid_data['Close'])**2)
rmse
# Out:
# 7.9248841931743
